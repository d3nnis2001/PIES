# %% [markdown]
# # Results 17.05.2023
#
# __Der normale Algo wie er bis jz steht__
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Results 17.05.2023
#
# __Changes: Only takes orderblocks from the past 2 days__
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 19.05.2023
#
# Änderung: Mit neuen Stoploss (High und Low der letzten 10 Candles)
#
# File: PIES_19.05.2023_0
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 19.05.2023
#
# Änderung: Mit den letzten 5 Candles (High, Low) als Stoploss
#
# File: PIES_19.05.2023_1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 19.05.2023
#
# Änderung: Der entry darf nur über/unter der ersten deviation line passieren
#
# File: PIES_19.05.2023_2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 20.05.2023
#
# Änderung: Bug mit stoploss fixed. Mit letzten 5 Candles als sl
#
# File: PIES_19.05.2023_2 updated
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 20.05.2023
#
# Änderung: Bug mit stoploss fixed. Mit letzten 10 Candles als sl
#
# File: PIES_19.05.2023_1 updated
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 20.05.2023
#
# Änderung: Neuer Datensatz ohne Lücken und mit den Daten von den letzten 2 Jahren. Dabei wird hier wieder mit den alten sl von der letzten Candle high/low gearbeitet und ohne der einschränkung, dass der entry über der ersten deviation passieren muss.
#
# File: PIES_20.05.2023_1.html
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 20.05.2023
#
# Änderung: Jetzt kommen zwei Dateien mit den selben Änderung des letzten Tries. Die erste beinhaltet alle Shorts die zweite beinhaltet alle Longs:
#
# Für Shorts:
#
# File: PIES_20.05.2023_2.html
#
# ![image.png](attachment:image.png)
#
# Für longs.
#
# File: PIES_20.05.2023_3.html
#
# ![image-2.png](attachment:image-2.png)
